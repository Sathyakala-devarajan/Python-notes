# %%
import pandas as pd


folder = r'D:\Greens technologies\Python\Notebook\Data'

books_df = pd.read_csv(f'{folder}/books.csv')
users_df = pd.read_csv(f'{folder}/users.csv')
ratings_df = pd.read_csv(f'{folder}/ratings.csv')
# Out:
# C:\Users\sathy\AppData\Local\Temp\ipykernel_976\3673699763.py:6: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books_df = pd.read_csv(f'{folder}/books.csv')

# %%
users_df
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
### ffill, bfill

# %%
users_df.ffill()
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia  18.0
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom  17.0
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa  17.0
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada  50.0
# 278856   278857           knoxville, tennessee, usa  50.0
# 278857   278858                dublin, n/a, ireland  50.0
#
# [278858 rows x 3 columns]

# %%
users_df.bfill()
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa  18.0
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia  17.0
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom  61.0
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa  50.0
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
users_df.fillna(method = 'ffill').fillna(method = 'bfill')
# Out:
# C:\Users\sathy\AppData\Local\Temp\ipykernel_976\1148547813.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   users_df.fillna(method = 'ffill').fillna(method = 'bfill')
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa  18.0
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia  18.0
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom  17.0
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa  17.0
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada  50.0
# 278856   278857           knoxville, tennessee, usa  50.0
# 278857   278858                dublin, n/a, ireland  50.0
#
# ...

# %%
import pandas as pd


folder = r'D:\Greens technologies\Python\Notebook\Data'

books_df = pd.read_csv(f'{folder}/books_finalised.csv')
user_df = pd.read_csv(f'{folder}/users_finalised.csv')
ratings_df = pd.read_csv(f'{folder}/ratings_finalised.csv')

# %%
books_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271355 entries, 0 to 271354
# Data columns (total 5 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271355 non-null  object
#  1   Book-Title           271355 non-null  object
#  2   Book-Author          271354 non-null  object
#  3   Year-Of-Publication  271355 non-null  int64
#  4   Publisher            271355 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 10.4+ MB

# %%
user_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   User-ID   278858 non-null  int64
#  1   Location  278858 non-null  object
#  2   Age       278858 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB

# %%
ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 4 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
#  3   BAND         1149780 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 35.1+ MB

# %%
set(books_df.columns) & set(user_df.columns)
# Out:
# set()

# %%
set(books_df.columns) & set(ratings_df.columns)
# Out:
# {'ISBN'}

# %%
set(user_df.columns) & set(ratings_df.columns)
# Out:
# {'User-ID'}

# %%
# df = books & ratins

# df = df & user

# %%
help(pd.merge)
# Out:
# Help on function merge in module pandas.core.reshape.merge:
#
# merge(left: 'DataFrame | Series', right: 'DataFrame | Series', how: 'MergeHow' = 'inner', on: 'IndexLabel | AnyArrayLike | None' = None, left_on: 'IndexLabel | AnyArrayLike | None' = None, right_on: 'IndexLabel | AnyArrayLike | None' = None, left_index: 'bool' = False, right_index: 'bool' = False, sort: 'bool' = False, suffixes: 'Suffixes' = ('_x', '_y'), copy: 'bool | None' = None, indicator: 'str | bool' = False, validate: 'str | None' = None) -> 'DataFrame'
#     Merge DataFrame or named Series objects with a database-style join.
#
#     A named Series object is treated as a DataFrame with a single named column.
#
#     The join is done on columns or indexes. If joining columns on
#     columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
#     on indexes or indexes on a column or columns, the index will be passed on.
# ...

# %%
df = books_df.merge(ratings_df, how ='left', on = 'ISBN')
df
# Out:
#                ISBN                                         Book-Title  \
# 0        0195153448                                Classical Mythology
# 1        0002005018                                       Clara Callan
# 2        0002005018                                       Clara Callan
# 3        0002005018                                       Clara Callan
# 4        0002005018                                       Clara Callan
# ...             ...                                                ...
# 1032334  0440400988                         There's a Bat in Bunk Five
# 1032335  0525447644                            From One to One Hundred
# 1032336  006008667X  Lily Dale : The True Story of the Town that Ta...
# 1032337  0192126040                        Republic (World's Classics)
# 1032338  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                   Book-Author  Year-Of-Publication  \
# 0          Mark P. O. Morford                 2005
# ...

# %%
books_df.shape, ratings_df.shape
# Out:
# ((271355, 5), (1149780, 4))

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ISBN, Book-Title, Book-Author, Year-Of-Publication, Publisher, User-ID, Book-Rating, BAND]
# Index: []

# %%
df['Book-Title'].value_counts()
# Out:
# Book-Title
# Wild Animus                                                                                                                       2502
# The Lovely Bones: A Novel                                                                                                         1295
# The Da Vinci Code                                                                                                                  899
# A Painted House                                                                                                                    838
# The Nanny Diaries: A Novel                                                                                                         828
#                                                                                                                                   ...
# La Romana                                                                                                                            1
# ...

# %%
df[df['Book-Title']=="Wild Animus"]
# Out:
#             ISBN   Book-Title   Book-Author  Year-Of-Publication Publisher  \
# 769   0971880107  Wild Animus  Rich Shapero                 2004   Too Far
# 770   0971880107  Wild Animus  Rich Shapero                 2004   Too Far
# 771   0971880107  Wild Animus  Rich Shapero                 2004   Too Far
# 772   0971880107  Wild Animus  Rich Shapero                 2004   Too Far
# 773   0971880107  Wild Animus  Rich Shapero                 2004   Too Far
# ...          ...          ...           ...                  ...       ...
# 3266  0971880107  Wild Animus  Rich Shapero                 2004   Too Far
# 3267  0971880107  Wild Animus  Rich Shapero                 2004   Too Far
# 3268  0971880107  Wild Animus  Rich Shapero                 2004   Too Far
# 3269  0971880107  Wild Animus  Rich Shapero                 2004   Too Far
# 3270  0971880107  Wild Animus  Rich Shapero                 2004   Too Far
#
#        User-ID  Book-Rating                  BAND
# ...

# %%
df = df.merge(user_df,on='User-ID',how='left')

df
# Out:
#                ISBN                                         Book-Title  \
# 0        0195153448                                Classical Mythology
# 1        0002005018                                       Clara Callan
# 2        0002005018                                       Clara Callan
# 3        0002005018                                       Clara Callan
# 4        0002005018                                       Clara Callan
# ...             ...                                                ...
# 1032334  0440400988                         There's a Bat in Bunk Five
# 1032335  0525447644                            From One to One Hundred
# 1032336  006008667X  Lily Dale : The True Story of the Town that Ta...
# 1032337  0192126040                        Republic (World's Classics)
# 1032338  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                   Book-Author  Year-Of-Publication  \
# 0          Mark P. O. Morford                 2005
# ...

# %%
df.sort_values('User-ID', ascending=False)
# Out:
#                ISBN                                         Book-Title  \
# 254461   0316184152                              Final Harvest : Poems
# 744956   0553275739                                         In Her Day
# 795461   0425163393         Kat Scratch Fever (Kat Colorado Mysteries)
# 262048   0375703063   A Virtuous Woman (Oprah's Book Club (Paperback))
# 179735   042516098X                                      Hornet's Nest
# ...             ...                                                ...
# 1032320  1874166633  Introducing Nietzsche (Foundations in Children...
# 1032321  0130897930                 Core Web Programming (2nd Edition)
# 1032322  020130998X  The Unified Modeling Language Reference Manual...
# 1032323  2268032019            Petite histoire de la dÃ?Â©sinformation
# 1032326  3442150663                                        Der Mossad.
#
#                        Book-Author  Year-Of-Publication  \
# 254461             Emily Dickinson                 1964
# ...

# %%
df.sort_values(['ISBN', 'User-ID'], ascending=[True, False], inplace=True)
df
# Out:
#                ISBN                                         Book-Title  \
# 1014530  0000913154  The Way Things Work: An Illustrated Encycloped...
# 968364   0001010565                                    Mog's Christmas
# 968363   0001010565                                    Mog's Christmas
# 542164   0001046438                                               Liar
# 788157   0001046713                       Twopence to Cross the Mersey
# ...             ...                                                ...
# 670647   B000234N76                                     Falling Angels
# 937721   B000234NC6  It Must've Been Something I Ate: The Return of...
# 829011   B00029DGGO                        Good Wife Strikes Back, The
# 916519   B0002JV9PY                               The Blockade Runners
# 916517   B0002K6K8O                               The Underground City
#
#                            Book-Author  Year-Of-Publication  \
# ...

# %%
indent = books_df.merge(ratings_df,on='ISBN',how='outer',indicator=True)
indent
# Out:
#                 ISBN Book-Title Book-Author  Year-Of-Publication Publisher  \
# 0         0330299891        NaN         NaN                  NaN       NaN
# 1         0330299891        NaN         NaN                  NaN       NaN
# 2         0375404120        NaN         NaN                  NaN       NaN
# 3         0375404120        NaN         NaN                  NaN       NaN
# 4         0586045007        NaN         NaN                  NaN       NaN
# ...              ...        ...         ...                  ...       ...
# 1150984     cn113107        NaN         NaN                  NaN       NaN
# 1150985   ooo7156103        NaN         NaN                  NaN       NaN
# 1150986   §423350229        NaN         NaN                  NaN       NaN
# 1150987  ´3499128624        NaN         NaN                  NaN       NaN
# 1150988    Ô½crosoft        NaN         NaN                  NaN       NaN
#
#           User-ID  Book-Rating                  BAND      _merge
# ...

# %%
indent['_merge'].value_counts()
# Out:
# _merge
# both          1031130
# right_only     118650
# left_only        1209
# Name: count, dtype: int64

# %%
indent[ indent['_merge'] == 'both' ]
# Out:
#                ISBN                                         Book-Title  \
# 177      0000913154  The Way Things Work: An Illustrated Encycloped...
# 178      0001010565                                    Mog's Christmas
# 179      0001010565                                    Mog's Christmas
# 183      0001046438                                               Liar
# 185      0001046713                       Twopence to Cross the Mersey
# ...             ...                                                ...
# 1150295  B000234N76                                     Falling Angels
# 1150296  B000234NC6  It Must've Been Something I Ate: The Return of...
# 1150297  B00029DGGO                        Good Wife Strikes Back, The
# 1150298  B0002JV9PY                               The Blockade Runners
# 1150299  B0002K6K8O                               The Underground City
#
#                            Book-Author  Year-Of-Publication  \
# ...

# %%
# string functions, Group by, aggregate, pivot, rename, apply

# %% [markdown]
# ##  str functions in pandas
#
# * split
# * contains
# * Upper
# * lower
# * extract
# * replace
# * map

# %%
df.head()
# Out:
#                ISBN                                         Book-Title  \
# 1014530  0000913154  The Way Things Work: An Illustrated Encycloped...
# 968364   0001010565                                    Mog's Christmas
# 968363   0001010565                                    Mog's Christmas
# 542164   0001046438                                               Liar
# 788157   0001046713                       Twopence to Cross the Mersey
#
#                            Book-Author  Year-Of-Publication  \
# 1014530  C. van Amerongen (translator)                 1967
# 968364                     Judith Kerr                 1992
# 968363                     Judith Kerr                 1992
# 542164                     Stephen Fry                    0
# 788157                 Helen Forrester                 1992
#
#                         Publisher   User-ID  Book-Rating                 BAND  \
# 1014530      Simon &amp; Schuster  171118.0          8.0  BEST SELLLING BOOKS
# ...

# %%
#split
df['Location'].str.split(',')
# Out:
# 1014530                     [toronto,  ontario,  canada]
# 968364           [felixstowe,  suffolk,  united kingdom]
# 968363                 [peterborough,  ontario,  canada]
# 542164               [london,  england,  united kingdom]
# 788157     [lisburn,  northern ireland,  united kingdom]
#                                ...
# 670647          [portela de sacavém,  loures,  portugal]
# 937721                      [seattle,  washington,  usa]
# 829011              [burnley,  england,  united kingdom]
# 916519            [sydney,  new south wales,  australia]
# 916517            [sydney,  new south wales,  australia]
# Name: Location, Length: 1032339, dtype: object

# %%
#split
df['Location'].str.split(',')[7]
# Out:
# ['ottawa', ' ontario', ' canada']

# %%
df['Location'].unique
# Out:
# <bound method Series.unique of 1014530                     toronto, ontario, canada
# 968364           felixstowe, suffolk, united kingdom
# 968363                 peterborough, ontario, canada
# 542164               london, england, united kingdom
# 788157     lisburn, northern ireland, united kingdom
#                              ...
# 670647          portela de sacavém, loures, portugal
# 937721                      seattle, washington, usa
# 829011              burnley, england, united kingdom
# 916519            sydney, new south wales, australia
# 916517            sydney, new south wales, australia
# Name: Location, Length: 1032339, dtype: object>

# %%
df.shape
# Out:
# (1032339, 10)

# %%
df['Location'].nunique()
# Out:
# 22480

# %%
#split
df['Location'].str.split(',',expand=True)
# Out:
#                           0                  1                2     3     4  \
# 1014530             toronto            ontario           canada  None  None
# 968364           felixstowe            suffolk   united kingdom  None  None
# 968363         peterborough            ontario           canada  None  None
# 542164               london            england   united kingdom  None  None
# 788157              lisburn   northern ireland   united kingdom  None  None
# ...                     ...                ...              ...   ...   ...
# 670647   portela de sacavém             loures         portugal  None  None
# 937721              seattle         washington              usa  None  None
# 829011              burnley            england   united kingdom  None  None
# 916519               sydney    new south wales        australia  None  None
# 916517               sydney    new south wales        australia  None  None
#
#             5     6
# 1014530  None  None
# ...

# %%
df[df['Book-Author'].isna()]
# Out:
#               ISBN                Book-Title Book-Author  Year-Of-Publication  \
# 800204  0751352497  A+ Quiz Masters:01 Earth         NaN                 1999
#
#                  Publisher  User-ID  Book-Rating                 BAND  \
# 800204  Dorling Kindersley  63714.0         10.0  BEST SELLLING BOOKS
#
#                                       Location   Age
# 800204  milton keynes, england, united kingdom  29.0

# %%
df['Book-Author'].fillna('Unknown Name', inplace=True)
# Out:
# C:\Users\sathy\AppData\Local\Temp\ipykernel_15780\3727037249.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Book-Author'].fillna('Unknown Name', inplace=True)

# %%
# contains
df[df['Book-Author'].str.contains('Judith')]
# Out:
#                ISBN                                         Book-Title  \
# 968364   0001010565                                    Mog's Christmas
# 968363   0001010565                                    Mog's Christmas
# 959291   0002154978  The Boy Who Couldn't Stop Washing: The Experie...
# 995677   0006617999                                   Mog and the Baby
# 788222   0006640621                              Mog the Forgetful Cat
# ...             ...                                                ...
# 1011279  8408023160                              El Oraculo De Cristal
# 1018771  8420432016  Cuando Hitler Robo El Conejo Rosa/When Hitler ...
# 941403   848667512X          El Gran Libro De LA Cocina Con Microondas
# 460124   8878240192                                           Scrupoli
# 899742   9681654412  Una Isla Como Tu: Island Like You (A La Orilla...
#
#                  Book-Author  Year-Of-Publication  \
# 968364           Judith Kerr                 1992
# ...

# %%
# contains
df[df['Book-Author'].str.contains('Karen')]
# df[df['Year-Of-Publication'] ==1992]
# Out:
#               ISBN                                       Book-Title  \
# 931965  0023888873  American Government Brief Ed.: Roots and Reform
# 864055  0025176501                     Brainstorm: A personal story
# 590529  0060007230                  Someone Like Him (Avon Romance)
# 590528  0060007230                  Someone Like Him (Avon Romance)
# 590527  0060007230                  Someone Like Him (Avon Romance)
# ...            ...                                              ...
# 578049  354860028X                                      Regenroman.
# 578048  354860028X                                      Regenroman.
# 578047  354860028X                                      Regenroman.
# 717488  3789135070                     Und wenn schon. ( Ab 12 J.).
# 919322  5551473511                Katapult (Kat Colorado Mysteries)
#
#                    Book-Author  Year-Of-Publication  \
# 931965          Karen O'Connor                 1992
# ...

# %%
# contains
df[df['Book-Author'].str.lower().str.contains('karen')]
# df[df['Book-Author'].str.contains('Karen')]
# Out:
#               ISBN                                       Book-Title  \
# 931965  0023888873  American Government Brief Ed.: Roots and Reform
# 864055  0025176501                     Brainstorm: A personal story
# 590529  0060007230                  Someone Like Him (Avon Romance)
# 590528  0060007230                  Someone Like Him (Avon Romance)
# 590527  0060007230                  Someone Like Him (Avon Romance)
# ...            ...                                              ...
# 578049  354860028X                                      Regenroman.
# 578048  354860028X                                      Regenroman.
# 578047  354860028X                                      Regenroman.
# 717488  3789135070                     Und wenn schon. ( Ab 12 J.).
# 919322  5551473511                Katapult (Kat Colorado Mysteries)
#
#                    Book-Author  Year-Of-Publication  \
# 931965          Karen O'Connor                 1992
# ...

# %%
df['Book-Author'].str.upper()
# Out:
# 1014530    C. VAN AMERONGEN (TRANSLATOR)
# 968364                       JUDITH KERR
# 968363                       JUDITH KERR
# 542164                       STEPHEN FRY
# 788157                   HELEN FORRESTER
#                        ...
# 670647                   TRACY CHEVALIER
# 937721               JEFFREY STEINGARTEN
# 829011                  ELIZABETH BUCHAN
# 916519                       JULES VERNE
# 916517                       JULES VERNE
# Name: Book-Author, Length: 1032339, dtype: object

# %%
df['Book-Author'].str.lower()
# Out:
# 1014530    c. van amerongen (translator)
# 968364                       judith kerr
# 968363                       judith kerr
# 542164                       stephen fry
# 788157                   helen forrester
#                        ...
# 670647                   tracy chevalier
# 937721               jeffrey steingarten
# 829011                  elizabeth buchan
# 916519                       jules verne
# 916517                       jules verne
# Name: Book-Author, Length: 1032339, dtype: object

# %%
df['Book-Author'].str.title()
# Out:
# 1014530    C. Van Amerongen (Translator)
# 968364                       Judith Kerr
# 968363                       Judith Kerr
# 542164                       Stephen Fry
# 788157                   Helen Forrester
#                        ...
# 670647                   Tracy Chevalier
# 937721               Jeffrey Steingarten
# 829011                  Elizabeth Buchan
# 916519                       Jules Verne
# 916517                       Jules Verne
# Name: Book-Author, Length: 1032339, dtype: object

# %%
df.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'User-ID', 'Book-Rating', 'BAND', 'Location', 'Age'],
#       dtype='object')

# %%
df.columns = [i.upper() for i in df.columns]

# %%
df
# Out:
#                ISBN                                         BOOK-TITLE  \
# 1014530  0000913154  The Way Things Work: An Illustrated Encycloped...
# 968364   0001010565                                    Mog's Christmas
# 968363   0001010565                                    Mog's Christmas
# 542164   0001046438                                               Liar
# 788157   0001046713                       Twopence to Cross the Mersey
# ...             ...                                                ...
# 670647   B000234N76                                     Falling Angels
# 937721   B000234NC6  It Must've Been Something I Ate: The Return of...
# 829011   B00029DGGO                        Good Wife Strikes Back, The
# 916519   B0002JV9PY                               The Blockade Runners
# 916517   B0002K6K8O                               The Underground City
#
#                            BOOK-AUTHOR  YEAR-OF-PUBLICATION  \
# ...

# %%
# extract
df['Base_Location'] = df['LOCATION'].str.extract(r'(usa|canada|spain|australia)')

# %%
df
# Out:
#                ISBN                                         BOOK-TITLE  \
# 1014530  0000913154  The Way Things Work: An Illustrated Encycloped...
# 968364   0001010565                                    Mog's Christmas
# 968363   0001010565                                    Mog's Christmas
# 542164   0001046438                                               Liar
# 788157   0001046713                       Twopence to Cross the Mersey
# ...             ...                                                ...
# 670647   B000234N76                                     Falling Angels
# 937721   B000234NC6  It Must've Been Something I Ate: The Return of...
# 829011   B00029DGGO                        Good Wife Strikes Back, The
# 916519   B0002JV9PY                               The Blockade Runners
# 916517   B0002K6K8O                               The Underground City
#
#                            BOOK-AUTHOR  YEAR-OF-PUBLICATION  \
# ...

# %%
## numpy 


# np.where (case)
# np.select

# %%
# np.where
import numpy as np
df['Location1'] = np.where(df['LOCATION'].str.contains('united kingdom'),'UK','Other country')
df
# Out:
#                ISBN                                         BOOK-TITLE  \
# 1014530  0000913154  The Way Things Work: An Illustrated Encycloped...
# 968364   0001010565                                    Mog's Christmas
# 968363   0001010565                                    Mog's Christmas
# 542164   0001046438                                               Liar
# 788157   0001046713                       Twopence to Cross the Mersey
# ...             ...                                                ...
# 670647   B000234N76                                     Falling Angels
# 937721   B000234NC6  It Must've Been Something I Ate: The Return of...
# 829011   B00029DGGO                        Good Wife Strikes Back, The
# 916519   B0002JV9PY                               The Blockade Runners
# 916517   B0002K6K8O                               The Underground City
#
#                            BOOK-AUTHOR  YEAR-OF-PUBLICATION  \
# ...

# %%
df['BOOK-RATING'].value_counts()
# Out:
# BOOK-RATING
# 0.0     647291
# 8.0      91804
# 10.0     71225
# 7.0      66401
# 9.0      60776
# 5.0      45355
# 6.0      31687
# 4.0       7617
# 3.0       5118
# 2.0       2375
# 1.0       1481
# Name: count, dtype: int64

# %%
# np.select
import numpy as np
conditions = [
    df['BOOK-RATING'] > 8, df['BOOK-RATING'] < 3
]

value = ['Best', 'Poor']

df['Performance'] = np.select(conditions, value, default='Avg')

# %%
df
# Out:
#                ISBN                                         BOOK-TITLE  \
# 1014530  0000913154  The Way Things Work: An Illustrated Encycloped...
# 968364   0001010565                                    Mog's Christmas
# 968363   0001010565                                    Mog's Christmas
# 542164   0001046438                                               Liar
# 788157   0001046713                       Twopence to Cross the Mersey
# ...             ...                                                ...
# 670647   B000234N76                                     Falling Angels
# 937721   B000234NC6  It Must've Been Something I Ate: The Return of...
# 829011   B00029DGGO                        Good Wife Strikes Back, The
# 916519   B0002JV9PY                               The Blockade Runners
# 916517   B0002K6K8O                               The Underground City
#
#                            BOOK-AUTHOR  YEAR-OF-PUBLICATION  \
# ...

# %%
df['Performance'].unique(), df['Performance'].value_counts()
# Out:
# (array(['Avg', 'Poor', 'Best'], dtype=object),
#  Performance
#  Poor    651147
#  Avg     249191
#  Best    132001
#  Name: count, dtype: int64)

# %%
df.loc[df['BOOK-RATING'] >8, 'Validation'] = 'Best'
df.loc[df['BOOK-RATING'] <3, 'Validation'] = 'Poor'
df.loc[(df['BOOK-RATING'] >=4) & (df['BOOK-RATING']<=8), 'Validation'] = 'Average'

# %%
df
# Out:
#                ISBN                                         BOOK-TITLE  \
# 1014530  0000913154  The Way Things Work: An Illustrated Encycloped...
# 968364   0001010565                                    Mog's Christmas
# 968363   0001010565                                    Mog's Christmas
# 542164   0001046438                                               Liar
# 788157   0001046713                       Twopence to Cross the Mersey
# ...             ...                                                ...
# 670647   B000234N76                                     Falling Angels
# 937721   B000234NC6  It Must've Been Something I Ate: The Return of...
# 829011   B00029DGGO                        Good Wife Strikes Back, The
# 916519   B0002JV9PY                               The Blockade Runners
# 916517   B0002K6K8O                               The Underground City
#
#                            BOOK-AUTHOR  YEAR-OF-PUBLICATION  \
# ...

# %%
# replace
df[df['PUBLISHER'] == 'Critica']
# Out:
#                ISBN                                         BOOK-TITLE  \
# 814290   8474239974                           Tratado de La Tolerancia
# 782116   8484320022                                 Las Leyes del Caos
# 699473   8484320650                               Carlos V y Su Tiempo
# 896132   8484320723            Cantaros, Los - Herejia y Crisis Social
# 694077   8484321061                             El Placer de Descubrir
# 684793   8484321207                                 Tiempo de Silencio
# 897879   8484321290                                        Stalingrado
# 897878   8484321290                                        Stalingrado
# 896234   848432155X                                               Nada
# 1012127  8484321606                                           Leyendas
# 866662   8484321789                              La Crisis de La Razon
# 895430   8484321886                                 La Vida del Buscon
# ...

# %%
# replace
df['PUBLISHER'] = df['PUBLISHER'].replace({'Critica':'Critica Ltd'})

# %%
df[df['PUBLISHER'].str.contains('Critica Ltd')]
# Out:
#                ISBN                                         BOOK-TITLE  \
# 814290   8474239974                           Tratado de La Tolerancia
# 782116   8484320022                                 Las Leyes del Caos
# 699473   8484320650                               Carlos V y Su Tiempo
# 896132   8484320723            Cantaros, Los - Herejia y Crisis Social
# 694077   8484321061                             El Placer de Descubrir
# 684793   8484321207                                 Tiempo de Silencio
# 897879   8484321290                                        Stalingrado
# 897878   8484321290                                        Stalingrado
# 896234   848432155X                                               Nada
# 1012127  8484321606                                           Leyendas
# 866662   8484321789                              La Crisis de La Razon
# 895430   8484321886                                 La Vida del Buscon
# ...

# %%
# map
df.loc[0:1032334, 'Gender'] = 'Male'
df.loc[1032335:, 'Gender'] = 'Female'

# %%
df
# Out:
#                ISBN                                         BOOK-TITLE  \
# 1014530  0000913154  The Way Things Work: An Illustrated Encycloped...
# 968364   0001010565                                    Mog's Christmas
# 968363   0001010565                                    Mog's Christmas
# 542164   0001046438                                               Liar
# 788157   0001046713                       Twopence to Cross the Mersey
# ...             ...                                                ...
# 670647   B000234N76                                     Falling Angels
# 937721   B000234NC6  It Must've Been Something I Ate: The Return of...
# 829011   B00029DGGO                        Good Wife Strikes Back, The
# 916519   B0002JV9PY                               The Blockade Runners
# 916517   B0002K6K8O                               The Underground City
#
#                            BOOK-AUTHOR  YEAR-OF-PUBLICATION  \
# ...

# %%
df['Gender']=df['Gender'].map({'Male':0, 'Female':1})

# %%
df['Performance']=df['Performance'].map({'Avg':2, 'Best':1, 'Poor':3})
df.head()
# Out:
#                ISBN                                         BOOK-TITLE  \
# 1014530  0000913154  The Way Things Work: An Illustrated Encycloped...
# 968364   0001010565                                    Mog's Christmas
# 968363   0001010565                                    Mog's Christmas
# 542164   0001046438                                               Liar
# 788157   0001046713                       Twopence to Cross the Mersey
#
#                            BOOK-AUTHOR  YEAR-OF-PUBLICATION  \
# 1014530  C. van Amerongen (translator)                 1967
# 968364                     Judith Kerr                 1992
# 968363                     Judith Kerr                 1992
# 542164                     Stephen Fry                    0
# 788157                 Helen Forrester                 1992
#
#                         PUBLISHER   USER-ID  BOOK-RATING                 BAND  \
# 1014530      Simon &amp; Schuster  171118.0          8.0  BEST SELLLING BOOKS
# ...

# %%
# to rename column

df.rename(columns={'USER-ID':'ID'},inplace=True)
df
# Out:
#                ISBN                                         BOOK-TITLE  \
# 1014530  0000913154  The Way Things Work: An Illustrated Encycloped...
# 968364   0001010565                                    Mog's Christmas
# 968363   0001010565                                    Mog's Christmas
# 542164   0001046438                                               Liar
# 788157   0001046713                       Twopence to Cross the Mersey
# ...             ...                                                ...
# 670647   B000234N76                                     Falling Angels
# 937721   B000234NC6  It Must've Been Something I Ate: The Return of...
# 829011   B00029DGGO                        Good Wife Strikes Back, The
# 916519   B0002JV9PY                               The Blockade Runners
# 916517   B0002K6K8O                               The Underground City
#
#                            BOOK-AUTHOR  YEAR-OF-PUBLICATION  \
# ...

# %%
df['BOOK-AUTHOR'].str.strip()
# Out:
# 1014530    C. van Amerongen (translator)
# 968364                       Judith Kerr
# 968363                       Judith Kerr
# 542164                       Stephen Fry
# 788157                   Helen Forrester
#                        ...
# 670647                   Tracy Chevalier
# 937721               Jeffrey Steingarten
# 829011                  Elizabeth Buchan
# 916519                       Jules Verne
# 916517                       Jules Verne
# Name: BOOK-AUTHOR, Length: 1032339, dtype: object

# %%
## group by -> agg


## based on user

# unique ->> distinct customer
#nunique -> count(distinct customers)
# value counts -> groupby count

# %%
# Aggrgate function
df['AGE'].mean(), df['AGE'].mode(), df['AGE'].median(), df['AGE'].std(), df['AGE'].sum(),df['AGE'].max(), df['AGE'].min()
# Out:
# (36.68463441121504,
#  0    34.751434
#  Name: AGE, dtype: float64,
#  34.75143370454978,
#  12.107186658327953,
#  37826627.08043617,
#  244.0,
#  0.0)

# %%
df.head()
# Out:
#                ISBN                                         BOOK-TITLE  \
# 1014530  0000913154  The Way Things Work: An Illustrated Encycloped...
# 968364   0001010565                                    Mog's Christmas
# 968363   0001010565                                    Mog's Christmas
# 542164   0001046438                                               Liar
# 788157   0001046713                       Twopence to Cross the Mersey
#
#                            BOOK-AUTHOR  YEAR-OF-PUBLICATION  \
# 1014530  C. van Amerongen (translator)                 1967
# 968364                     Judith Kerr                 1992
# 968363                     Judith Kerr                 1992
# 542164                     Stephen Fry                    0
# 788157                 Helen Forrester                 1992
#
#                         PUBLISHER        ID  BOOK-RATING                 BAND  \
# 1014530      Simon &amp; Schuster  171118.0          8.0  BEST SELLLING BOOKS
# ...

# %%
## for particular author how many book he write, year of publication, max_rating
user_grp = df.groupby(['BOOK-AUTHOR']).agg(Books_wrote = ('BOOK-TITLE','nunique'), Users_read =('ID','nunique'),
                               Year_published=('YEAR-OF-PUBLICATION',min), max_rating =('BOOK-RATING',max))
user_grp
# Out:
# C:\Users\sathy\AppData\Local\Temp\ipykernel_15780\786802203.py:2: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   user_grp = df.groupby(['BOOK-AUTHOR']).agg(Books_wrote = ('BOOK-TITLE','nunique'), Users_read =('ID','nunique'),
# C:\Users\sathy\AppData\Local\Temp\ipykernel_15780\786802203.py:2: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   user_grp = df.groupby(['BOOK-AUTHOR']).agg(Books_wrote = ('BOOK-TITLE','nunique'), Users_read =('ID','nunique'),
#                                   Books_wrote  Users_read  Year_published  \
# BOOK-AUTHOR
# ...

# %%
df.to_csv('Final data.csv', index=False)

# %%
# user >3
user_grp[user_grp['Books_wrote']>3]
# Out:
#                        Books_wrote  Users_read  Year_published  max_rating
# BOOK-AUTHOR
# A A Milne                        5          14               0        10.0
# A. A. Attanasio                  7          29            1989        10.0
# A. A. Milne                     46         114            1960        10.0
# A. B. Yehoshua                   5          12            1993         8.0
# A. Bates                         7          27            1989        10.0
# ...                            ...         ...             ...         ...
# Zora Neale Hurston              17         212               0        10.0
# Zsuzsanna E. Budapest            5          22            1989        10.0
# bell hooks                       7          25            1981        10.0
# tk                               6          11            1999         8.0
# x x                              4           4            2002        10.0
#
# [12459 rows x 4 columns]

# %%
df[df['BOOK-AUTHOR']=='x x']
# Out:
#               ISBN                        BOOK-TITLE BOOK-AUTHOR  \
# 961188  1591050367  An American Redneck in Hong Kong         x x
# 961190  1591050804                       Winter Fire         x x
# 980090  1931696810                     Mating Season         x x
# 980091  1931696837                          Unlawful         x x
#
#         YEAR-OF-PUBLICATION         PUBLISHER        ID  BOOK-RATING  \
# 961188                 2002  NovelBooks, Inc.  187517.0          8.0
# 961190                 2002  NovelBooks, Inc.  126253.0          9.0
# 980090                 2002  NovelBooks, Inc.  145747.0          5.0
# 980091                 2002  NovelBooks, Inc.  248948.0         10.0
#
#                         BAND                     LOCATION        AGE  \
# 961188   BEST SELLLING BOOKS      brooklyn, new york, usa  28.000000
# 961190   BEST SELLLING BOOKS    meriden, connecticut, usa  34.751434
# 980090  AVERAGE SELLER BOOKS      madison, wisconsin, usa  34.751434
# ...
