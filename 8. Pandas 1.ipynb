# %% [markdown]
# # Pandas
# * Data cleaning, Analyzing, Exploring, Manipulating
# * Data stuctures
#   1. Series ---> 1 D
#   2. Data frame ----> 2D

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### create series

# %%
# series
ser = [3, 6, 8, 9]
ser
# Out:
# [3, 6, 8, 9]

# %%
df = pd.Series(ser)
df
# Out:
# 0    3
# 1    6
# 2    8
# 3    9
# dtype: int64

# %%
type(df), df.ndim
# Out:
# (pandas.core.series.Series, 1)

# %% [markdown]
# #### create dataframe

# %%
df = pd.DataFrame(ser)
df
# Out:
#    0
# 0  3
# 1  6
# 2  8
# 3  9

# %%
type(df), df.ndim
# Out:
# (pandas.core.frame.DataFrame, 2)

# %%
my_data=np.random.randint(0,101,(4,3))
my_data
# Out:
# array([[ 76,   9,  26],
#        [ 57,  46,  96],
#        [ 57, 100, 100],
#        [ 52,  30,  79]])

# %%
my_index=["india","Japan","Australia","newziland"]
my_index
# Out:
# ['india', 'Japan', 'Australia', 'newziland']

# %%
column=["jan","feb","mar"]
column
# Out:
# ['jan', 'feb', 'mar']

# %%
df=pd.DataFrame(my_data,index=my_index,columns=column)
df
# Out:
#            jan  feb  mar
# india       76    9   26
# Japan       57   46   96
# Australia   57  100  100
# newziland   52   30   79

# %%
type(df), df.ndim
# Out:
# (pandas.core.frame.DataFrame, 2)

# %% [markdown]
# #### Read the dataset
# * csv(.csv) file
# * excel(.xlsx) file
# * sql file, etc
# * json
# * html

# %%
# To read the dataset

df = pd.read_excel(r'D:\Greens technologies\Python\Notebook\Data\combined_excel.xlsx')
df
# Out:
#    Unnamed: 0                          Unnamed: 1 Unnamed: 2
# 0         NaN                                 NaN        NaN
# 1         NaN                                 NaN        NaN
# 2         NaN                                 NaN        NaN
# 3         NaN                                 NaN        NaN
# 4         NaN                                 NaN        NaN
# 5         NaN                                 NaN        NaN
# 6     User-ID                            Location        Age
# 7           1                  nyc, new york, usa         18
# 8           2           stockton, california, usa         18
# 9           3     moscow, yukon territory, russia        NaN
# 10          4           porto, v.n.gaia, portugal         17
# 11          5  farnborough, hants, united kingdom         17

# %%
# To read the dataset
master_file = r'D:\Greens technologies\Python\Notebook\Data'
df = pd.read_excel(f'{master_file}/combined_excel.xlsx')
df
# Out:
#    Unnamed: 0                          Unnamed: 1 Unnamed: 2
# 0         NaN                                 NaN        NaN
# 1         NaN                                 NaN        NaN
# 2         NaN                                 NaN        NaN
# 3         NaN                                 NaN        NaN
# 4         NaN                                 NaN        NaN
# 5         NaN                                 NaN        NaN
# 6     User-ID                            Location        Age
# 7           1                  nyc, new york, usa         18
# 8           2           stockton, california, usa         18
# 9           3     moscow, yukon territory, russia        NaN
# 10          4           porto, v.n.gaia, portugal         17
# 11          5  farnborough, hants, united kingdom         17

# %%
# skiprows
df = pd.read_excel(f'{master_file}/combined_excel.xlsx', skiprows=7)
df
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa  18.0
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom  17.0

# %%
# select sheet
df = pd.read_excel(f'{master_file}/combined_excel.xlsx', sheet_name = 'check')
df
# Out:
#      NAME DESIGNATION  JOINING
# 0  sathya         DE      2018
# 1    sasi         DE      2018
# 2    Mani          DE     2019
# 3  sathya          DS     2019
# 4    sasi          DS     2019
# 5    Mani          DS     2020

# %%
df = pd.read_excel(f'{master_file}/combined_excel.xlsx', sheet_name = 'Sheet3')
df
# Out:
#     User-ID                            Location   Age
# 0       NaN                                 NaN   NaN
# 1       NaN                                 NaN   NaN
# 2       NaN                                 NaN   NaN
# 3       NaN                                 NaN   NaN
# 4       NaN                                 NaN   NaN
# 5       NaN                                 NaN   NaN
# 6       1.0                  nyc, new york, usa  18.0
# 7       2.0           stockton, california, usa  18.0
# 8       3.0     moscow, yukon territory, russia   NaN
# 9       4.0                                 NaN  17.0
# 10      5.0  farnborough, hants, united kingdom  17.0

# %%
# how (all  ---> all columns is null)
df.dropna(how ='all')
# Out:
#     User-ID                            Location   Age
# 6       1.0                  nyc, new york, usa  18.0
# 7       2.0           stockton, california, usa  18.0
# 8       3.0     moscow, yukon territory, russia   NaN
# 9       4.0                                 NaN  17.0
# 10      5.0  farnborough, hants, united kingdom  17.0

# %%
# how (any  ---> is any one of the column 
df.dropna(how ='any')
# Out:
#     User-ID                            Location   Age
# 6       1.0                  nyc, new york, usa  18.0
# 7       2.0           stockton, california, usa  18.0
# 10      5.0  farnborough, hants, united kingdom  17.0

# %%
df=pd.read_csv("tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 2         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 3         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 4         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 240       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 241       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 242       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 243       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 244       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name     CC Number Payment ID
# ...

# %% [markdown]
# #### Top 5 and Bottom 5 records

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 2       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 3       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 4       23.68  3.31    Male     No  Sun  Dinner     2             11.84
#
#            Payer Name     CC Number Payment ID
# 0  Christy Cunningham  3.560330e+15    Sun2959
# 1  Christy Cunningham  3.560330e+15    Sun2959
# 2      Douglas Tucker  4.478070e+15    Sun4608
# 3      Travis Walters  6.011810e+15    Sun4458
# 4    Nathaniel Harris  4.676140e+15    Sun5260

# %%
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       16.99  1.01  Female     No  Sun  Dinner     2              8.49
#
#            Payer Name     CC Number Payment ID
# 0  Christy Cunningham  3.560330e+15    Sun2959
# 1  Christy Cunningham  3.560330e+15    Sun2959

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 240       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 241       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 242       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 243       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 244       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name     CC Number Payment ID
# 240    Michael Avila  5.296070e+15    Sat2657
# 241   Monica Sanders  3.506810e+15    Sat1766
# 242       Keith Wong  6.011890e+15    Sat3880
# 243     Dennis Dixon  4.375220e+12      Sat17
# 244  Michelle Hardin  3.511450e+15    Thur672

# %%
df.tail(2)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 243       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 244       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name     CC Number Payment ID
# 243     Dennis Dixon  4.375220e+12      Sat17
# 244  Michelle Hardin  3.511450e+15    Thur672

# %% [markdown]
# #### To get the name of all the columns

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %% [markdown]
# #### To get index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=245, step=1)

# %% [markdown]
# #### Rename the column

# %%
df=df.rename(columns={"Payer Name":"payer_name","CC Number":"cc_number", "Payment ID":"Payment_ID"})
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 2         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 3         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 4         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 240       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 241       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 242       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 243       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 244       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              payer_name     cc_number Payment_ID
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        245 non-null    float64
#  1   tip               245 non-null    float64
#  2   sex               245 non-null    object
#  3   smoker            245 non-null    object
#  4   day               245 non-null    object
#  5   time              245 non-null    object
#  6   size              245 non-null    int64
#  7   price_per_person  245 non-null    float64
#  8   payer_name        245 non-null    object
#  9   cc_number         245 non-null    float64
#  10  Payment_ID        245 non-null    object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 21.2+ KB

# %% [markdown]
# #### Statistical description

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     cc_number
# count  245.000000  245.000000  245.000000        245.000000  2.450000e+02
# mean    19.774531    2.990163    2.567347          7.890653  2.567564e+15
# std      8.885946    1.386631    0.949846          2.908510  2.365337e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.370000    2.000000    2.000000          5.800000  3.042230e+13
# 50%     17.780000    2.880000    2.000000          7.260000  3.526520e+15
# 75%     24.080000    3.550000    3.000000          9.390000  4.550550e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596450e+15

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        245.0  1.977453e+01  8.885946e+00  3.070000e+00
# tip               245.0  2.990163e+00  1.386631e+00  1.000000e+00
# size              245.0  2.567347e+00  9.498464e-01  1.000000e+00
# price_per_person  245.0  7.890653e+00  2.908510e+00  2.880000e+00
# cc_number         245.0  2.567564e+15  2.365337e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.337000e+01  1.778000e+01  2.408000e+01  5.081000e+01
# tip               2.000000e+00  2.880000e+00  3.550000e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.260000e+00  9.390000e+00  2.027000e+01
# cc_number         3.042230e+13  3.526520e+15  4.550550e+15  6.596450e+15

# %% [markdown]
# #### To extract out single column or multiple column

# %%
df["total_bill"]
# Out:
# 0      16.99
# 1      16.99
# 2      10.34
# 3      21.01
# 4      23.68
#        ...
# 240    29.03
# 241    27.18
# 242    22.67
# 243    17.82
# 244    18.78
# Name: total_bill, Length: 245, dtype: float64

# %%
df[["total_bill"]]
# Out:
#      total_bill
# 0         16.99
# 1         16.99
# 2         10.34
# 3         21.01
# 4         23.68
# ..          ...
# 240       29.03
# 241       27.18
# 242       22.67
# 243       17.82
# 244       18.78
#
# [245 rows x 1 columns]

# %%
df[["total_bill","tip"]].head(3)
# Out:
#    total_bill   tip
# 0       16.99  1.01
# 1       16.99  1.01
# 2       10.34  1.66

# %% [markdown]
# #### Adding new column

# %%
df["tip_percentage"]=df['tip']/df["total_bill"]*100

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 2         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 3         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 4         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 240       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 241       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 242       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 243       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 244       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              payer_name     cc_number Payment_ID  tip_percentage
# ...

# %%
df["tip_percentage"]=round(df['tip']/df["total_bill"]*100,2)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 2         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 3         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 4         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 240       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 241       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 242       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 243       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 244       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              payer_name     cc_number Payment_ID  tip_percentage
# ...

# %%
df['Total amount'] = df['total_bill']+df['tip']
df.head()
# Out:
#   Payment_ID  total_bill   tip     sex smoker  day    time  price_per_person  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner              8.49
# 1    Sun2959       16.99  1.01  Female     No  Sun  Dinner              8.49
# 2    Sun4608       10.34  1.66    Male     No  Sun  Dinner              3.45
# 3    Sun4458       21.01  3.50    Male     No  Sun  Dinner              7.00
# 4    Sun5260       23.68  3.31    Male     No  Sun  Dinner             11.84
#
#            payer_name  Total amount
# 0  Christy Cunningham         18.00
# 1  Christy Cunningham         18.00
# 2      Douglas Tucker         12.00
# 3      Travis Walters         24.51
# 4    Nathaniel Harris         26.99

# %%
df["tip_percentage"]
# Out:
# 0       5.94
# 1       5.94
# 2      16.05
# 3      16.66
# 4      13.98
#        ...
# 240    20.39
# 241     7.36
# 242     8.82
# 243     9.82
# 244    15.97
# Name: tip_percentage, Length: 245, dtype: float64

# %% [markdown]
# #### Drop the column

# %%
df.drop("tip_percentage", axis = 1)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 2         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 3         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 4         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 240       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 241       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 242       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 243       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 244       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              payer_name     cc_number Payment_ID
# ...

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 2       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 3       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 4       23.68  3.31    Male     No  Sun  Dinner     2             11.84
#
#            payer_name     cc_number Payment_ID  tip_percentage
# 0  Christy Cunningham  3.560330e+15    Sun2959            5.94
# 1  Christy Cunningham  3.560330e+15    Sun2959            5.94
# 2      Douglas Tucker  4.478070e+15    Sun4608           16.05
# 3      Travis Walters  6.011810e+15    Sun4458           16.66
# 4    Nathaniel Harris  4.676140e+15    Sun5260           13.98

# %%
# in case of deleting multiple column
df.drop(['cc_number','tip_percentage'],axis=1, inplace=True)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 2       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 3       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 4       23.68  3.31    Male     No  Sun  Dinner     2             11.84
#
#            payer_name Payment_ID
# 0  Christy Cunningham    Sun2959
# 1  Christy Cunningham    Sun2959
# 2      Douglas Tucker    Sun4608
# 3      Travis Walters    Sun4458
# 4    Nathaniel Harris    Sun5260

# %% [markdown]
# #### How to set any column as index

# %%
df=df.set_index("Payment_ID")
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment_ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          payer_name
# Payment_ID
# Sun2959                 8.49  Christy Cunningham
# Sun2959                 8.49  Christy Cunningham
# Sun4608                 3.45      Douglas Tucker
# Sun4458                 7.00      Travis Walters
# Sun5260                11.84    Nathaniel Harris

# %% [markdown]
# #### In order to reset index

# %%
df=df.reset_index()
df.head()
# Out:
#   Payment_ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 2    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 3    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 4    Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
#
#    price_per_person          payer_name
# 0              8.49  Christy Cunningham
# 1              8.49  Christy Cunningham
# 2              3.45      Douglas Tucker
# 3              7.00      Travis Walters
# 4             11.84    Nathaniel Harris

# %% [markdown]
# #### To select any specific rows with index position

# %%
df.iloc[0] # rows, columns
# Out:
# Payment_ID                     Sun2959
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# payer_name          Christy Cunningham
# Name: 0, dtype: object

# %%
df.iloc[18]
# Out:
# Payment_ID               Sun2998
# total_bill                 16.29
# tip                         3.71
# sex                         Male
# smoker                        No
# day                          Sun
# time                      Dinner
# size                           3
# price_per_person            5.43
# payer_name          John Pittman
# Name: 18, dtype: object

# %%
df.columns
# Out:
# Index(['Payment_ID', 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time',
#        'size', 'price_per_person', 'payer_name'],
#       dtype='object')

# %%
df.iloc[:,0]
# Out:
# 0      Sun2959
# 1      Sun2959
# 2      Sun4608
# 3      Sun4458
# 4      Sun5260
#         ...
# 240    Sat2657
# 241    Sat1766
# 242    Sat3880
# 243      Sat17
# 244    Thur672
# Name: Payment_ID, Length: 245, dtype: object

# %%
df.iloc[:,5]
# Out:
# 0       Sun
# 1       Sun
# 2       Sun
# 3       Sun
# 4       Sun
#        ...
# 240     Sat
# 241     Sat
# 242     Sat
# 243     Sat
# 244    Thur
# Name: day, Length: 245, dtype: object

# %%
df.iloc[:11,:3]
# Out:
#    Payment_ID  total_bill   tip
# 0     Sun2959       16.99  1.01
# 1     Sun2959       16.99  1.01
# 2     Sun4608       10.34  1.66
# 3     Sun4458       21.01  3.50
# 4     Sun5260       23.68  3.31
# 5     Sun2251       24.59  3.61
# 6     Sun9679       25.29  4.71
# 7     Sun5985        8.77  2.00
# 8     Sun8157       26.88  3.12
# 9     Sun6820       15.04  1.96
# 10    Sun3775       14.78  3.23

# %%
df.iloc[11:16,5:8]
# Out:
#     day    time  size
# 11  Sun  Dinner     2
# 12  Sun  Dinner     4
# 13  Sun  Dinner     2
# 14  Sun  Dinner     4
# 15  Sun  Dinner     2

# %%
df.iloc[1:5]
# Out:
#   Payment_ID  total_bill   tip     sex smoker  day    time  size  \
# 1    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 2    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 3    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 4    Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
#
#    price_per_person          payer_name
# 1              8.49  Christy Cunningham
# 2              3.45      Douglas Tucker
# 3              7.00      Travis Walters
# 4             11.84    Nathaniel Harris

# %%
df.loc[5:10,'tip']
# Out:
# 5     3.61
# 6     4.71
# 7     2.00
# 8     3.12
# 9     1.96
# 10    3.23
# Name: tip, dtype: float64

# %%
df.loc[20:25, 'Payment_ID']
# Out:
# 20    Sat9213
# 21    Sat1709
# 22    Sat9618
# 23    Sat9786
# 24     Sat239
# 25    Sat6236
# Name: Payment_ID, dtype: object

# %% [markdown]
# #### How to drop the row and Column

# %%
df.drop(1,axis=0)
# Out:
#     Payment_ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 2      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 3      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 4      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 5      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 240    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 241    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 242    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 243      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 244    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          payer_name
# 0                8.49  Christy Cunningham
# 2                3.45      Douglas Tucker
# ...

# %%
df.drop('size',axis=1, inplace=True)

# %%
df.drop('time',axis=1)
# Out:
#     Payment_ID  total_bill   tip     sex smoker   day  price_per_person  \
# 0      Sun2959       16.99  1.01  Female     No   Sun              8.49
# 1      Sun2959       16.99  1.01  Female     No   Sun              8.49
# 2      Sun4608       10.34  1.66    Male     No   Sun              3.45
# 3      Sun4458       21.01  3.50    Male     No   Sun              7.00
# 4      Sun5260       23.68  3.31    Male     No   Sun             11.84
# ..         ...         ...   ...     ...    ...   ...               ...
# 240    Sat2657       29.03  5.92    Male     No   Sat              9.68
# 241    Sat1766       27.18  2.00  Female    Yes   Sat             13.59
# 242    Sat3880       22.67  2.00    Male    Yes   Sat             11.34
# 243      Sat17       17.82  1.75    Male     No   Sat              8.91
# 244    Thur672       18.78  3.00  Female     No  Thur              9.39
#
#              payer_name
# 0    Christy Cunningham
# 1    Christy Cunningham
# 2        Douglas Tucker
# ...

# %% [markdown]
# #### Condition filtering
# * condtion filtering
# * filter by single condition
# * filter by multiple condtion
# * check against multiple values

# %%
new_df=pd.read_csv("tips.csv")
new_df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       16.99  1.01  Female     No  Sun  Dinner     2              8.49
#
#            Payer Name     CC Number Payment ID
# 0  Christy Cunningham  3.560330e+15    Sun2959
# 1  Christy Cunningham  3.560330e+15    Sun2959

# %%
new_df["total_bill"]>40 # let filter out for the bill values greater than 40 dollars
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 240    False
# 241    False
# 242    False
# 243    False
# 244    False
# Name: total_bill, Length: 245, dtype: bool

# %%
new_df[new_df["total_bill"]>40] # let filter out for the bill values greater than 40 dollars
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 60        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 96        40.17   4.73    Male    Yes   Fri  Dinner     4             10.04
# 103       44.30   2.50  Female    Yes   Sat  Dinner     3             14.77
# 143       41.19   5.00    Male     No  Thur   Lunch     5              8.24
# 157       48.17   5.00    Male     No   Sun  Dinner     6              8.03
# 171       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 183       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# 185       40.55   3.00    Male    Yes   Sun  Dinner     2             20.27
# 198       43.11   5.00  Female    Yes  Thur   Lunch     4             10.78
# 213       48.33   9.00    Male     No   Sat  Dinner     4             12.08
#
#           Payer Name     CC Number Payment ID
# 60       Brian Ortiz  6.596450e+15    Sat8139
# ...

# %%
new_df['sex'].count()
# Out:
# 245

# %%
new_df[new_df["sex"]=="Female"].count()
# Out:
# total_bill          88
# tip                 88
# sex                 88
# smoker              88
# day                 88
# time                88
# size                88
# price_per_person    88
# Payer Name          88
# CC Number           88
# Payment ID          88
# dtype: int64

# %%
# how to filter out with multiple condition
# and --> & ==> where both condition need to be true
# OR --> | ==> where either of condition must be true

# %%
new_df[(new_df["total_bill"]>40) & (new_df["sex"]=="Female")]
# Out:
#      total_bill  tip     sex smoker   day    time  size  price_per_person  \
# 103       44.30  2.5  Female    Yes   Sat  Dinner     3             14.77
# 198       43.11  5.0  Female    Yes  Thur   Lunch     4             10.78
#
#         Payer Name     CC Number Payment ID
# 103  Heather Cohen  3.797710e+14    Sat6240
# 198    Brooke Soto  5.544900e+15   Thur9313

# %%
new_df[(new_df["total_bill"]>40) | (new_df["sex"]=="Female")]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 5         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# 12        35.26  5.00  Female     No   Sun  Dinner     4              8.82
# 15        14.83  3.02  Female     No   Sun  Dinner     2              7.42
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 227       10.09  2.00  Female    Yes   Fri   Lunch     2              5.04
# 230       22.12  2.88  Female    Yes   Sat  Dinner     2             11.06
# 239       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 241       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 244       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name     CC Number Payment ID
# ...

# %%
option=["Sat","Sun"]
new_df[new_df["day"].isin(option)]
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1         16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 2         10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 3         21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 4         23.68  3.31    Male     No  Sun  Dinner     2             11.84
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 239       35.83  4.67  Female     No  Sat  Dinner     3             11.94
# 240       29.03  5.92    Male     No  Sat  Dinner     3              9.68
# 241       27.18  2.00  Female    Yes  Sat  Dinner     2             13.59
# 242       22.67  2.00    Male    Yes  Sat  Dinner     2             11.34
# 243       17.82  1.75    Male     No  Sat  Dinner     2              8.91
#
#              Payer Name     CC Number Payment ID
# ...

# %% [markdown]
# #### Sorting method in pandas

# %%
df.sort_values("tip") # default ascending = True --- ascending order
# Out:
#     Payment_ID  total_bill    tip     sex smoker   day    time  \
# 68     Sat3455        3.07   1.00  Female    Yes   Sat  Dinner
# 237    Sat5032       12.60   1.00    Male    Yes   Sat  Dinner
# 93     Fri3780        5.75   1.00  Female    Yes   Fri  Dinner
# 112    Sat4801        7.25   1.00  Female     No   Sat  Dinner
# 0      Sun2959       16.99   1.01  Female     No   Sun  Dinner
# ..         ...         ...    ...     ...    ...   ...     ...
# 142   Thur1025       34.30   6.70    Male     No  Thur   Lunch
# 60     Sat8139       48.27   6.73    Male     No   Sat  Dinner
# 24      Sat239       39.42   7.58    Male     No   Sat  Dinner
# 213    Sat4590       48.33   9.00    Male     No   Sat  Dinner
# 171    Sat1954       50.81  10.00    Male    Yes   Sat  Dinner
#
#      price_per_person          payer_name  Total amount
# 68               3.07       Tiffany Brock          4.07
# 237              6.30       Matthew Myers         13.60
# ...

# %%
df.sort_values(['price_per_person'], ascending=False) #descending order
# Out:
#     Payment_ID  total_bill    tip     sex smoker  day    time  \
# 185    Sun5140       40.55   3.00    Male    Yes  Sun  Dinner
# 180    Sun9851       34.63   3.55    Male    Yes  Sun  Dinner
# 171    Sat1954       50.81  10.00    Male    Yes  Sat  Dinner
# 176    Sun5109       32.90   3.11    Male    Yes  Sun  Dinner
# 238    Sat2929       32.83   1.17    Male    Yes  Sat  Dinner
# ..         ...         ...    ...     ...    ...  ...     ...
# 173    Sun9209        7.25   5.15    Male    Yes  Sun  Dinner
# 2      Sun4608       10.34   1.66    Male     No  Sun  Dinner
# 17     Sun9715       10.33   1.67  Female     No  Sun  Dinner
# 68     Sat3455        3.07   1.00  Female    Yes  Sat  Dinner
# 93     Fri3780        5.75   1.00  Female    Yes  Fri  Dinner
#
#      price_per_person        payer_name  Total amount
# 185             20.27       Stephen Cox         43.55
# 180             17.32      Brian Bailey         38.18
# 171             16.94     Gregory Clark         60.81
# ...

# %%
df.sort_values(["tip","Payment_ID"])
# Out:
#     Payment_ID  total_bill    tip     sex smoker   day    time  \
# 93     Fri3780        5.75   1.00  Female    Yes   Fri  Dinner
# 68     Sat3455        3.07   1.00  Female    Yes   Sat  Dinner
# 112    Sat4801        7.25   1.00  Female     No   Sat  Dinner
# 237    Sat5032       12.60   1.00    Male    Yes   Sat  Dinner
# 0      Sun2959       16.99   1.01  Female     No   Sun  Dinner
# ..         ...         ...    ...     ...    ...   ...     ...
# 142   Thur1025       34.30   6.70    Male     No  Thur   Lunch
# 60     Sat8139       48.27   6.73    Male     No   Sat  Dinner
# 24      Sat239       39.42   7.58    Male     No   Sat  Dinner
# 213    Sat4590       48.33   9.00    Male     No   Sat  Dinner
# 171    Sat1954       50.81  10.00    Male    Yes   Sat  Dinner
#
#      price_per_person          payer_name  Total amount
# 93               2.88        Leah Ramirez          6.75
# 68               3.07       Tiffany Brock          4.07
# ...

# %%
df.sort_values(["Payment_ID", "tip"])
# Out:
#     Payment_ID  total_bill   tip     sex smoker   day    time  \
# 99      Fri144       21.01  3.00    Male    Yes   Fri  Dinner
# 95     Fri2318       22.75  3.25  Female     No   Fri  Dinner
# 97     Fri3159       27.28  4.00    Male    Yes   Fri  Dinner
# 93     Fri3780        5.75  1.00  Female    Yes   Fri  Dinner
# 101    Fri4106       11.35  2.50  Female    Yes   Fri  Dinner
# ..         ...         ...   ...     ...    ...   ...     ...
# 130   Thur9424       22.82  2.18    Male     No  Thur   Lunch
# 80    Thur9501       17.29  2.71    Male     No  Thur   Lunch
# 118   Thur9593       10.65  1.50  Female     No  Thur   Lunch
# 192    Thur967       19.81  4.19  Female    Yes  Thur   Lunch
# 197   Thur9862       10.34  2.00    Male    Yes  Thur   Lunch
#
#      price_per_person      payer_name  Total amount
# 99              10.50      Michael Li         24.01
# 95              11.38     Jamie Garza         26.00
# 97              13.64     Eric Carter         31.28
# ...

# %% [markdown]
# #### Check the data types

# %%
df.dtypes
# Out:
# Payment_ID           object
# total_bill          float64
# tip                 float64
# sex                  object
# smoker               object
# day                  object
# time                 object
# price_per_person    float64
# payer_name           object
# Total amount        float64
# dtype: object

# %%
object_columns = df.select_dtypes(include=['object']).columns
object_columns
# Out:
# Index(['Payment_ID', 'sex', 'smoker', 'day', 'time', 'payer_name'], dtype='object')

# %%
numeric_column = df.select_dtypes(include=['int', 'float'])
numeric_column
# Out:
#      total_bill   tip  price_per_person  Total amount
# 0         16.99  1.01              8.49         18.00
# 1         16.99  1.01              8.49         18.00
# 2         10.34  1.66              3.45         12.00
# 3         21.01  3.50              7.00         24.51
# 4         23.68  3.31             11.84         26.99
# ..          ...   ...               ...           ...
# 240       29.03  5.92              9.68         34.95
# 241       27.18  2.00             13.59         29.18
# 242       22.67  2.00             11.34         24.67
# 243       17.82  1.75              8.91         19.57
# 244       18.78  3.00              9.39         21.78
#
# [245 rows x 4 columns]

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 df.corr()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11036, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11034 cols = data.columns
#   11035 idx = cols.copy()
# > 11036 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11038 if method == "pearson":
#   11039     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# -> 1981 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1982 if result.dtype is not dtype:
#    1983     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
numeric_column.corr() # correlation
# Out:
#                   total_bill       tip  price_per_person  Total amount
# total_bill          1.000000  0.674598          0.647100      0.994613
# tip                 0.674598  1.000000          0.344703      0.747484
# price_per_person    0.647100  0.344703          1.000000      0.630719
# Total amount        0.994613  0.747484          0.630719      1.000000

# %% [markdown]
# #### value counts/unique/nunique/replace/map func

# %%
df["sex"].value_counts()
# Out:
# sex
# Male      157
# Female     88
# Name: count, dtype: int64

# %%
df["day"].value_counts()
# Out:
# day
# Sat     87
# Sun     77
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (245, 10)

# %%
df["day"].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df["time"].unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
df["day"].nunique()
# Out:
# 4

# %%
df["time"].nunique()
# Out:
# 2

# %%
df["Payment_ID"].nunique()
# Out:
# 243

# %%
df["sex"].replace(["Female","Male"],["F","M"])
# Out:
# 0      F
# 1      F
# 2      M
# 3      M
# 4      M
#       ..
# 240    M
# 241    F
# 242    M
# 243    M
# 244    F
# Name: sex, Length: 245, dtype: object

# %%
df.head(2)
# Out:
#   Payment_ID  total_bill   tip     sex smoker  day    time  price_per_person  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner              8.49
# 1    Sun2959       16.99  1.01  Female     No  Sun  Dinner              8.49
#
#            payer_name  Total amount
# 0  Christy Cunningham          18.0
# 1  Christy Cunningham          18.0

# %%
df["sex"].map({'Female':'F', 'Male':'M'})
# Out:
# 0      F
# 1      F
# 2      M
# 3      M
# 4      M
#       ..
# 240    M
# 241    F
# 242    M
# 243    M
# 244    F
# Name: sex, Length: 245, dtype: object

# %% [markdown]
# #### How to treat duplicate values

# %%
df = pd.read_csv("tips.csv")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 2       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 3       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 4       23.68  3.31    Male     No  Sun  Dinner     2             11.84
#
#            Payer Name     CC Number Payment ID
# 0  Christy Cunningham  3.560330e+15    Sun2959
# 1  Christy Cunningham  3.560330e+15    Sun2959
# 2      Douglas Tucker  4.478070e+15    Sun4608
# 3      Travis Walters  6.011810e+15    Sun4458
# 4    Nathaniel Harris  4.676140e+15    Sun5260

# %%
df.duplicated()
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 240    False
# 241    False
# 242    False
# 243    False
# 244    False
# Length: 245, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df = df.drop_duplicates()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 2       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 3       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 4       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 5       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name     CC Number Payment ID
# 0  Christy Cunningham  3.560330e+15    Sun2959
# 2      Douglas Tucker  4.478070e+15    Sun4608
# 3      Travis Walters  6.011810e+15    Sun4458
# 4    Nathaniel Harris  4.676140e+15    Sun5260
# 5        Tonya Carter  4.832730e+15    Sun2251

# %%
# use of between function
df[df["total_bill"].between(10,20)]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 2         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 9         15.04  1.96    Male     No   Sun  Dinner     2              7.52
# 10        14.78  3.23    Male     No   Sun  Dinner     2              7.39
# 11        10.27  1.71    Male     No   Sun  Dinner     2              5.14
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 235       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 236       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# 237       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 243       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 244       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name     CC Number Payment ID
# ...

# %%
df[df["total_bill"].between(1,5)]
# Out:
#     total_bill  tip     sex smoker  day    time  size  price_per_person  \
# 68        3.07  1.0  Female    Yes  Sat  Dinner     1              3.07
#
#        Payer Name     CC Number Payment ID
# 68  Tiffany Brock  4.359490e+15    Sat3455

# %% [markdown]
# #### nlargest and nsmallest

# %%
#show me the 5 largest tip
df.nlargest(5,"tip")
# Out:
#      total_bill    tip   sex smoker   day    time  size  price_per_person  \
# 171       50.81  10.00  Male    Yes   Sat  Dinner     3             16.94
# 213       48.33   9.00  Male     No   Sat  Dinner     4             12.08
# 24        39.42   7.58  Male     No   Sat  Dinner     4              9.86
# 60        48.27   6.73  Male     No   Sat  Dinner     4             12.07
# 142       34.30   6.70  Male     No  Thur   Lunch     6              5.72
#
#           Payer Name     CC Number Payment ID
# 171    Gregory Clark  5.473850e+15    Sat1954
# 213  Alex Williamson  6.762190e+11    Sat4590
# 24    Lance Peterson  3.542580e+15     Sat239
# 60       Brian Ortiz  6.596450e+15    Sat8139
# 142   Steven Carlson  3.526520e+15   Thur1025

# %%
# show me the 5 smallest tips
df.nsmallest(5,"tip")
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 68         3.07  1.00  Female    Yes  Sat  Dinner     1              3.07
# 93         5.75  1.00  Female    Yes  Fri  Dinner     2              2.88
# 112        7.25  1.00  Female     No  Sat  Dinner     1              7.25
# 237       12.60  1.00    Male    Yes  Sat  Dinner     2              6.30
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
#
#              Payer Name     CC Number Payment ID
# 68        Tiffany Brock  4.359490e+15    Sat3455
# 93         Leah Ramirez  3.508910e+15    Fri3780
# 112         Terri Jones  3.559220e+15    Sat4801
# 237       Matthew Myers  3.543680e+15    Sat5032
# 0    Christy Cunningham  3.560330e+15    Sun2959

# %% [markdown]
# #### Random sample of the dataset by the number or percentage

# %%
df.sample(8)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 123       14.26  2.50    Male     No  Thur   Lunch     2              7.13
# 172       15.81  3.16    Male    Yes   Sat  Dinner     2              7.90
# 85        15.98  2.03    Male     No  Thur   Lunch     2              7.99
# 159       13.39  2.61  Female     No   Sun  Dinner     2              6.70
# 113       38.07  4.00    Male     No   Sun  Dinner     3             12.69
# 107       20.49  4.06    Male    Yes   Sat  Dinner     2             10.24
# 109       18.24  3.76    Male     No   Sat  Dinner     2              9.12
# 207       26.59  3.41    Male    Yes   Sat  Dinner     3              8.86
#
#         Payer Name     CC Number Payment ID
# 123   Perry Garcia  1.800350e+14   Thur3579
# 172     David Hall  5.020040e+11    Sat6750
# 85     Jason Jones  4.442980e+15   Thur1944
# 159    Ashley Boyd  3.571090e+15     Sun982
# 113     Jeff Lopez  3.572870e+15     Sun591
# ...

# %% [markdown]
# #### Combining dataframe --> Concatenation

# %%
data_one={"A":["A0","A1","A2","A3"],"B":["B0","B1","B2","B3"]}
data_one
# Out:
# {'A': ['A0', 'A1', 'A2', 'A3'], 'B': ['B0', 'B1', 'B2', 'B3']}

# %%
df1 = pd.DataFrame(data_one)
df1
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %%
data_Two={"C":["C0","C1","C2","C3"],"D":["D0","D1","D2","D3"]}
df2 = pd.DataFrame(data_Two)
df2
# Out:
#     C   D
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3

# %%
# concate them along column
pd.concat([df1,df2],axis=1)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
# concate them along column
pd.concat([df1,df2],axis=0)
# Out:
#      A    B    C    D
# 0   A0   B0  NaN  NaN
# 1   A1   B1  NaN  NaN
# 2   A2   B2  NaN  NaN
# 3   A3   B3  NaN  NaN
# 0  NaN  NaN   C0   D0
# 1  NaN  NaN   C1   D1
# 2  NaN  NaN   C2   D2
# 3  NaN  NaN   C3   D3

# %%
df2.columns, df1.columns
df2.columns=df1.columns

# %%
df2
# Out:
#     A   B
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3

# %%
df1
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %%
pd.concat([df1,df2],axis=0)
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3

# %% [markdown]
# #### Combining Dataframe --> Merging
# * this is analogous to Join in sql
# * there are three way of merging how= inner,outer , left or right

# %%
registrations = pd.DataFrame({'reg_id':[1,2,3,4],'name':['Andrew','Bobo','Claire','David']})
logins = pd.DataFrame({'log_id':[1,2,3,4],'name':['Xavier','Andrew','Yolanda','Bobo']})

# %%
registrations
# Out:
#    reg_id    name
# 0       1  Andrew
# 1       2    Bobo
# 2       3  Claire
# 3       4   David

# %%
logins
# Out:
#    log_id     name
# 0       1   Xavier
# 1       2   Andrew
# 2       3  Yolanda
# 3       4     Bobo

# %%
pd.merge(registrations,logins,how="inner",on="name")
# Out:
#    reg_id    name  log_id
# 0       1  Andrew       2
# 1       2    Bobo       4

# %%
#left
pd.merge(registrations,logins,how="left",on="name")
# Out:
#    reg_id    name  log_id
# 0       1  Andrew     2.0
# 1       2    Bobo     4.0
# 2       3  Claire     NaN
# 3       4   David     NaN

# %%
#Right
pd.merge(registrations,logins,how="right",on="name")
# Out:
#    reg_id     name  log_id
# 0     NaN   Xavier       1
# 1     1.0   Andrew       2
# 2     NaN  Yolanda       3
# 3     2.0     Bobo       4

# %%
# outer merge
pd.merge(registrations,logins,how="outer",on="name")
# Out:
#    reg_id     name  log_id
# 0     1.0   Andrew     2.0
# 1     2.0     Bobo     4.0
# 2     3.0   Claire     NaN
# 3     4.0    David     NaN
# 4     NaN   Xavier     1.0
# 5     NaN  Yolanda     3.0
