# %%
# library
import pandas as pd
import numpy as np

# %% [markdown]
# # Data frame   ----> ETL (Extract Transform Load)
# * Exploration,
# * Analysis,
# * cleaning
# * Manipulation

# %%
# Books, Ratings, Users

# %%
# data frame
master_file = r'D:\Greens technologies\Python\Notebook\Data'
book_df = pd.read_csv(f'{master_file}/books.csv')
book_df
# Out:
# C:\Users\sathy\AppData\Local\Temp\ipykernel_10724\148273281.py:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   book_df = pd.read_csv(f'{master_file}/books.csv')
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# ...

# %%
# data frame
book_df = pd.read_csv(r'D:\Greens technologies\Python\Notebook\Data\books.csv')
book_df
# Out:
# C:\Users\sathy\AppData\Local\Temp\ipykernel_10724\619611892.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   book_df = pd.read_csv(r'D:\Greens technologies\Python\Notebook\Data\books.csv')
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# ...

# %% [markdown]
# #### To get the name of all the columns

# %%
book_df.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %% [markdown]
# #### To get the index

# %%
book_df.index
# Out:
# RangeIndex(start=0, stop=271360, step=1)

# %% [markdown]
# #### To get the information about the dataset

# %%
book_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271358 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %%
book_df.describe()
# Out:
#               ISBN      Book-Title      Book-Author  Year-Of-Publication  \
# count       271360          271360           271358               271360
# unique      271360          242135           102022                  202
# top     0195153448  Selected Poems  Agatha Christie                 2002
# freq             1              27              632                13903
#
#         Publisher                                        Image-URL-S  \
# count      271358                                             271360
# unique      16807                                             271044
# top     Harlequin  http://images.amazon.com/images/P/185326119X.0...
# freq         7535                                                  2
#
#                                               Image-URL-M  \
# count                                              271360
# unique                                             271044
# top     http://images.amazon.com/images/P/185326119X.0...
# ...

# %% [markdown]
# #### To view the null values

# %%
book_df.isna().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %% [markdown]
# ### Remove column
# * usecols   --> using keyword  ---> essential columns
# * filter method  --> essential columns
# * drop  ---> unwanted columns

# %%
col = ['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher'] # essential columns
# usecols function
book_df = pd.read_csv(f'{master_file}/books.csv', usecols = col)
book_df
# Out:
# C:\Users\sathy\AppData\Local\Temp\ipykernel_10724\3544426756.py:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   book_df = pd.read_csv(f'{master_file}/books.csv', usecols = col)
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# ...

# %%
# col = ['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher'] # essential columns
# usecols function
book_df = pd.read_csv(f'{master_file}/books.csv', usecols = ['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher'])
book_df
# Out:
# C:\Users\sathy\AppData\Local\Temp\ipykernel_608\1933897987.py:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   book_df = pd.read_csv(f'{master_file}/books.csv', usecols = ['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher'])
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# ...

# %%
book_df.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication',
#        'Publisher'],
#       dtype='object')

# %%
# filter method
book_df[['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher']]
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
# drop method -- unwanted columns
book_df.drop(columns = ['Image-URL-S', 'Image-URL-M', 'Image-URL-L']) # inplace=True ----> it chenged in dataframe (overwrite)
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
book_df.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
# inplace = True ----> it chenged in dataframe (overwrite)
book_df.drop(columns = ['Image-URL-S', 'Image-URL-M', 'Image-URL-L'], inplace=True)

# %%
book_df
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
book_df.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication',
#        'Publisher'],
#       dtype='object')

# %%
# To check the duplicates 
book_df.duplicated().sum()
# Out:
# 0

# %%
book_df.drop_duplicates()
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
book_df1 = book_df[book_df['Year-Of-Publication'].duplicated()]
book_df1
# Out:
#               ISBN                                         Book-Title  \
# 4       0393045218                             The Mummies of Urumchi
# 5       0399135782                             The Kitchen God's Wife
# 9       074322678X            Where You'll Find Me: And Other Stories
# 11      080652121X  Hitler's Secret Bankers: The Myth of Swiss Neu...
# 13      1552041778                                           Jane Doe
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                 Book-Author Year-Of-Publication  \
# 4           E. J. W. Barber                1999
# ...

# %%
# unique
book_df['Year-Of-Publication'].unique(), book_df['Year-Of-Publication'].nunique()
# Out:
# (array([2002, 2001, 1991, 1999, 2000, 1993, 1996, 1988, 2004, 1998, 1994,
#         2003, 1997, 1983, 1979, 1995, 1982, 1985, 1992, 1986, 1978, 1980,
#         1952, 1987, 1990, 1981, 1989, 1984, 0, 1968, 1961, 1958, 1974,
#         1976, 1971, 1977, 1975, 1965, 1941, 1970, 1962, 1973, 1972, 1960,
#         1966, 1920, 1956, 1959, 1953, 1951, 1942, 1963, 1964, 1969, 1954,
#         1950, 1967, 2005, 1957, 1940, 1937, 1955, 1946, 1936, 1930, 2011,
#         1925, 1948, 1943, 1947, 1945, 1923, 2020, 1939, 1926, 1938, 2030,
#         1911, 1904, 1949, 1932, 1928, 1929, 1927, 1931, 1914, 2050, 1934,
#         1910, 1933, 1902, 1924, 1921, 1900, 2038, 2026, 1944, 1917, 1901,
#         2010, 1908, 1906, 1935, 1806, 2021, '2000', '1995', '1999', '2004',
#         '2003', '1990', '1994', '1986', '1989', '2002', '1981', '1993',
#         '1983', '1982', '1976', '1991', '1977', '1998', '1992', '1996',
#         '0', '1997', '2001', '1974', '1968', '1987', '1984', '1988',
# ...

# %%
book_df.isna().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# dtype: int64

# %%
# To get the null rows
book_df[book_df['Book-Author'].isna()]
# Out:
#               ISBN                                         Book-Title  \
# 118033  0751352497                           A+ Quiz Masters:01 Earth
# 187689  9627982032  The Credit Suisse Guide to Managing Your Perso...
#
#        Book-Author Year-Of-Publication                       Publisher
# 118033         NaN                1999              Dorling Kindersley
# 187689         NaN                1995  Edinburgh Financial Publishing

# %% [markdown]
# # To remove null values
# * fillna  ----> mean, mode, median
# * dropna ----> remove

# %%
book_df['Book-Author'] = book_df['Book-Author'].fillna('Unknown Name')

# %%
book_df[book_df['Book-Author'].isna()]
# Out:
# Empty DataFrame
# Columns: [ISBN, Book-Title, Book-Author, Year-Of-Publication, Publisher]
# Index: []

# %%
book_df[book_df['Publisher'].isna()]
# Out:
#               ISBN       Book-Title      Book-Author Year-Of-Publication  \
# 128890  193169656X      Tyrant Moon  Elaine Corvidae                2002
# 129037  1931696993  Finders Keepers  Linnea Sinclair                2001
#
#        Publisher
# 128890       NaN
# 129037       NaN

# %%
book_df = book_df.dropna()

# %%
book_df[book_df['Publisher'].isna()]
# Out:
# Empty DataFrame
# Columns: [ISBN, Book-Title, Book-Author, Year-Of-Publication, Publisher]
# Index: []

# %%
book_df[book_df['Book-Author'] == 'Unknown Name']
# Out:
#               ISBN                                         Book-Title  \
# 118033  0751352497                           A+ Quiz Masters:01 Earth
# 187689  9627982032  The Credit Suisse Guide to Managing Your Perso...
#
#          Book-Author Year-Of-Publication                       Publisher
# 118033  Unknown Name                1999              Dorling Kindersley
# 187689  Unknown Name                1995  Edinburgh Financial Publishing

# %%
book_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 271358 entries, 0 to 271359
# Data columns (total 5 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271358 non-null  object
#  1   Book-Title           271358 non-null  object
#  2   Book-Author          271358 non-null  object
#  3   Year-Of-Publication  271358 non-null  object
#  4   Publisher            271358 non-null  object
# dtypes: object(5)
# memory usage: 12.4+ MB

# %%
book_df['Year-Of-Publication'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 book_df['Year-Of-Publication'].astype(int)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6640, in NDFrame.astype(self, dtype, copy, errors)
#    6634     results = [
#    6635         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6636     ]
#    6638 else:
#    6639     # else, only a single dtype is given
# -> 6640     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6641     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6642     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
# ...

# %%
book_df['Year-Of-Publication'].unique()
# Out:
# array([2002, 2001, 1991, 1999, 2000, 1993, 1996, 1988, 2004, 1998, 1994,
#        2003, 1997, 1983, 1979, 1995, 1982, 1985, 1992, 1986, 1978, 1980,
#        1952, 1987, 1990, 1981, 1989, 1984, 0, 1968, 1961, 1958, 1974,
#        1976, 1971, 1977, 1975, 1965, 1941, 1970, 1962, 1973, 1972, 1960,
#        1966, 1920, 1956, 1959, 1953, 1951, 1942, 1963, 1964, 1969, 1954,
#        1950, 1967, 2005, 1957, 1940, 1937, 1955, 1946, 1936, 1930, 2011,
#        1925, 1948, 1943, 1947, 1945, 1923, 2020, 1939, 1926, 1938, 2030,
#        1911, 1904, 1949, 1932, 1928, 1929, 1927, 1931, 1914, 2050, 1934,
#        1910, 1933, 1902, 1924, 1921, 1900, 2038, 2026, 1944, 1917, 1901,
#        2010, 1908, 1906, 1935, 1806, 2021, '2000', '1995', '1999', '2004',
#        '2003', '1990', '1994', '1986', '1989', '2002', '1981', '1993',
#        '1983', '1982', '1976', '1991', '1977', '1998', '1992', '1996',
#        '0', '1997', '2001', '1974', '1968', '1987', '1984', '1988',
# ...

# %%
# method 1 to get required values
book_df[(book_df['Year-Of-Publication'] == 'DK Publishing Inc') | (book_df['Year-Of-Publication'] == 'Gallimard')]
# Out:
#               ISBN                                         Book-Title  \
# 209538  078946697X  DK Readers: Creating the X-Men, How It All Beg...
# 220731  2070426769  Peuple du ciel, suivi de 'Les Bergers\";Jean-M...
# 221678  0789466953  DK Readers: Creating the X-Men, How Comic Book...
#
#        Book-Author Year-Of-Publication  \
# 209538        2000   DK Publishing Inc
# 220731        2003           Gallimard
# 221678        2000   DK Publishing Inc
#
#                                                 Publisher
# 209538  http://images.amazon.com/images/P/078946697X.0...
# 220731  http://images.amazon.com/images/P/2070426769.0...
# 221678  http://images.amazon.com/images/P/0789466953.0...

# %%
# method 2 to get required value using isin
book_df[book_df['Year-Of-Publication'].isin(['DK Publishing Inc', 'Gallimard'])]
# Out:
#               ISBN                                         Book-Title  \
# 209538  078946697X  DK Readers: Creating the X-Men, How It All Beg...
# 220731  2070426769  Peuple du ciel, suivi de 'Les Bergers\";Jean-M...
# 221678  0789466953  DK Readers: Creating the X-Men, How Comic Book...
#
#        Book-Author Year-Of-Publication  \
# 209538        2000   DK Publishing Inc
# 220731        2003           Gallimard
# 221678        2000   DK Publishing Inc
#
#                                                 Publisher
# 209538  http://images.amazon.com/images/P/078946697X.0...
# 220731  http://images.amazon.com/images/P/2070426769.0...
# 221678  http://images.amazon.com/images/P/0789466953.0...

# %%
book_df = book_df[~book_df['Year-Of-Publication'].isin(['DK Publishing Inc', 'Gallimard'])]
book_df
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
book_df['Year-Of-Publication'] = book_df['Year-Of-Publication'].astype(int)

# %%
book_df['Year-Of-Publication'].unique(), book_df['Year-Of-Publication'].nunique()
# Out:
# (array([2002, 2001, 1991, 1999, 2000, 1993, 1996, 1988, 2004, 1998, 1994,
#         2003, 1997, 1983, 1979, 1995, 1982, 1985, 1992, 1986, 1978, 1980,
#         1952, 1987, 1990, 1981, 1989, 1984,    0, 1968, 1961, 1958, 1974,
#         1976, 1971, 1977, 1975, 1965, 1941, 1970, 1962, 1973, 1972, 1960,
#         1966, 1920, 1956, 1959, 1953, 1951, 1942, 1963, 1964, 1969, 1954,
#         1950, 1967, 2005, 1957, 1940, 1937, 1955, 1946, 1936, 1930, 2011,
#         1925, 1948, 1943, 1947, 1945, 1923, 2020, 1939, 1926, 1938, 2030,
#         1911, 1904, 1949, 1932, 1928, 1929, 1927, 1931, 1914, 2050, 1934,
#         1910, 1933, 1902, 1924, 1921, 1900, 2038, 2026, 1944, 1917, 1901,
#         2010, 1908, 1906, 1935, 1806, 2021, 2012, 2006, 1909, 2008, 1378,
#         1919, 1922, 1897, 2024, 1376, 2037]),
#  116)

# %%
book_df[book_df['Year-Of-Publication'] ==0]
# Out:
#               ISBN                                         Book-Title  \
# 176     3150000335                                   Kabale Und Liebe
# 188     342311360X                            Die Liebe in Den Zelten
# 288     0571197639                        Poisonwood Bible Edition Uk
# 351     3596214629       Herr Der Fliegen (Fiction, Poetry and Drama)
# 542     8845229041  Biblioteca Universale Rizzoli: Sulla Sponda De...
# ...            ...                                                ...
# 270794  014029953X                         Foe (Essential.penguin S.)
# 270913  0340571187                                     Postmens House
# 271094  8427201079                           El Misterio De Sittaford
# 271182  0887781721                                          Tom Penny
# 271196  3150013763                                     Der Hofmeister
#
#                    Book-Author  Year-Of-Publication  \
# 176                   Schiller                    0
# ...

# %%
book_df[book_df['Year-Of-Publication']!=0]
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author  Year-Of-Publication  \
# 0         Mark P. O. Morford                 2002
# ...

# %%
# Rating

# master_file = r'D:\Greens technologies\Python\Notebook\Data'
# ratings_df = pd.read_csv(f'{master_file}/Ratings.csv')
# ratings_df

ratings_df = pd.read_csv(r'D:\Greens technologies\Python\Notebook\Data\Ratings.csv')
ratings_df
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB

# %%
ratings_df.isna().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
ratings_df.duplicated().sum()
# Out:
# 0

# %%
ratings_df[ratings_df['User-ID'] == 276729]
# Out:
#    User-ID        ISBN  Book-Rating
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ratings_df.drop_duplicates()
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
ratings_df.drop_duplicates(['User-ID','ISBN'])
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
# select sheet
df = pd.read_excel(f'{master_file}/combined_excel.xlsx', sheet_name = 'check')
df
# Out:
#      NAME DESIGNATION  JOINING
# 0  sathya         DE      2018
# 1    sasi         DE      2018
# 2    Mani          DE     2019
# 3  sathya          DS     2019
# 4    sasi          DS     2019
# 5    Mani          DS     2020

# %%
df.drop_duplicates()
# Out:
#      NAME DESIGNATION  JOINING
# 0  sathya         DE      2018
# 1    sasi         DE      2018
# 2    Mani          DE     2019
# 3  sathya          DS     2019
# 4    sasi          DS     2019
# 5    Mani          DS     2020

# %%
df.drop_duplicates('NAME')  # keep --> first (default)
# Out:
#      NAME DESIGNATION  JOINING
# 0  sathya         DE      2018
# 1    sasi         DE      2018
# 2    Mani          DE     2019

# %%
df.drop_duplicates('NAME', keep='last')  # keep --> first, last
# Out:
#      NAME DESIGNATION  JOINING
# 3  sathya          DS     2019
# 4    sasi          DS     2019
# 5    Mani          DS     2020

# %%
# sort_values
df.sort_values(['NAME'], ascending=False) # ascending = False --> descending
# Out:
#      NAME DESIGNATION  JOINING
# 0  sathya         DE      2018
# 3  sathya          DS     2019
# 1    sasi         DE      2018
# 4    sasi          DS     2019
# 2    Mani          DE     2019
# 5    Mani          DS     2020

# %%
ratings_df[ratings_df['ISBN'].duplicated()]
# Out:
#          User-ID        ISBN  Book-Rating
# 91        276798  3442437407            0
# 295       276861  360893541X            9
# 296       276861  3608935428            9
# 297       276861  3608935436            9
# 397       276904  0440414121           10
# ...          ...         ...          ...
# 1149774   276704  0876044011            0
# 1149775   276704  1563526298            9
# 1149776   276706  0679447156            0
# 1149777   276709  0515107662           10
# 1149778   276721  0590442449           10
#
# [809224 rows x 3 columns]

# %%
ratings_df[ratings_df['ISBN'].duplicated()]['ISBN'].unique().tolist()
# Out:
# ['3442437407',
#  '360893541X',
#  '3608935428',
#  '3608935436',
#  '0440414121',
#  '3596122279',
#  '0971880107',
#  '0684867621',
#  '0061097101',
#  '0345446860',
#  '0380731851',
#  '0316666343',
#  '0330332775',
#  '0446605484',
#  '0679745203',
#  '080410946X',
#  '0375703861',
#  '0380807343',
#  '0440241073',
#  '3548603203',
#  '0689817851',
#  '0804114986',
#  '044023722X',
#  '002542730X',
#  '014029628X',
#  '0380600129',
#  '0380702843',
#  '0385504209',
#  '0425104273',
#  '0425115801',
#  '0425154092',
#  '0425175405',
#  '0440225701',
#  '0446604801',
#  '0446611212',
#  '0553268880',
#  '0553572997',
#  '0553581112',
#  '0553581929',
#  '0553586122',
#  '0609804138',
#  '0684872153',
#  '0767903382',
#  '0811801802',
#  '0836218833',
#  '0345452550',
#  '0312195516',
#  '0449221512',
#  '0553279556',
#  '0671003755',
#  '0345443284',
#  '0425191184',
#  '0440213320',
#  '0385482388',
#  '0452282152',
#  '0440241537',
#  '0446613843',
#  '0515133302',
# ...

# %%
ratings_df[ratings_df['ISBN'].duplicated()]['ISBN'].nunique()
# Out:
# 143511

# %%
# users --> Users

master_file = r'D:\Greens technologies\Python\Notebook\Data'
users_df = pd.read_csv(f'{master_file}/Users.csv')
users_df
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   User-ID   278858 non-null  int64
#  1   Location  278858 non-null  object
#  2   Age       168096 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB

# %%
users_df.isna().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
# fill Null value
mean_age = users_df['Age'].mean()   # avg
mean_age
# Out:
# 34.75143370454978

# %%
mode_age = users_df['Age'].mode()    # repeted
mode_age
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
users_df['Age'].median()   #middle value
# Out:
# 32.0

# %%
users_df['Age'].value_counts()  # group
# Out:
# Age
# 24.0     5687
# 25.0     5618
# 26.0     5547
# 23.0     5456
# 27.0     5383
#          ...
# 168.0       1
# 132.0       1
# 159.0       1
# 186.0       1
# 127.0       1
# Name: count, Length: 165, dtype: int64

# %%
users_df['Age'] = users_df['Age'].fillna(mean_age)

# %%
users_df.isna().sum()
# Out:
# User-ID     0
# Location    0
# Age         0
# dtype: int64

# %%
users_df
# Out:
#         User-ID                            Location        Age
# 0             1                  nyc, new york, usa  34.751434
# 1             2           stockton, california, usa  18.000000
# 2             3     moscow, yukon territory, russia  34.751434
# 3             4           porto, v.n.gaia, portugal  17.000000
# 4             5  farnborough, hants, united kingdom  34.751434
# ...         ...                                 ...        ...
# 278853   278854               portland, oregon, usa  34.751434
# 278854   278855  tacoma, washington, united kingdom  50.000000
# 278855   278856           brampton, ontario, canada  34.751434
# 278856   278857           knoxville, tennessee, usa  34.751434
# 278857   278858                dublin, n/a, ireland  34.751434
#
# [278858 rows x 3 columns]

# %%
# To save the file 

book_df.to_csv('books_finalised.csv', index = False)
ratings_df.to_csv('ratings_finalised.csv', index = False)
users_df.to_csv('users_finalised.csv', index=False)
